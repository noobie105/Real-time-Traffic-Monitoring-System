# %% [markdown]
# **Converting Labels to Detection**

# %%
# !pip install ultralytics opencv-python torch torchvision torchaudio psutil pyqt5

from google.colab import drive
drive.mount('/content/drive')
import os
import glob
import numpy as np
import time

LABELS_DIR = '/content/drive/MyDrive/Regnum/Labels'
OUTPUT_LABELS_DIR = '/content/drive/MyDrive/Regnum/Labels_detection'

os.makedirs(OUTPUT_LABELS_DIR, exist_ok=True)

def polygon_to_bbox(coords):
    coords = np.array(coords).reshape(-1, 2)
    x_min, y_min = coords.min(axis=0)
    x_max, y_max = coords.max(axis=0)
    cx = (x_min + x_max) / 2
    cy = (y_min + y_max) / 2
    w = x_max - x_min
    h = y_max - y_min
    return [cx, cy, w, h]

for label_path in glob.glob(os.path.join(LABELS_DIR, '*.txt')):
    base_name = os.path.basename(label_path)
    output_path = os.path.join(OUTPUT_LABELS_DIR, base_name)

    with open(label_path, 'r') as f:
        lines = f.readlines()

    new_lines = []
    for line in lines:
        parts = line.strip().split()
        if not parts:
            continue
        class_id = int(parts[0])
        coords = [float(p) for p in parts[1:]]

        if len(coords) == 4:
            bbox = coords
        elif len(coords) % 2 == 0 and len(coords) >= 6:

            bbox = polygon_to_bbox(coords)
        else:
            print(f"Skipping invalid line in {base_name}: {line.strip()}")
            continue

        new_line = f"{class_id} {' '.join(f'{v:.6f}' for v in bbox)}\n"
        new_lines.append(new_line)

    if new_lines:
        with open(output_path, 'w') as f:
            f.writelines(new_lines)
    else:
        print(f"No valid annotations in {base_name} → skipping")

print("Conversion complete")
print(f"Converted labels: {len(os.listdir(OUTPUT_LABELS_DIR))}")
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.8-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (5.9.5)
# Collecting pyqt5
#   Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Collecting PyQt5-sip<13,>=12.15 (from pyqt5)
#   Downloading pyqt5_sip-12.18.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (495 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyqt5)
#   Downloading pyqt5_qt5-5.15.18-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Downloading ultralytics-8.4.8-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.1 MB/s eta 0:00:00
# Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 118.6 MB/s eta 0:00:00
# Downloading pyqt5_qt5-5.15.18-py3-none-manylinux2014_x86_64.whl (60.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 17.2 MB/s eta 0:00:00
# Downloading pyqt5_sip-12.18.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.whl (282 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.4/282.4 kB 24.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, pyqt5, ultralytics-thop, ultralytics
# Successfully installed PyQt5-Qt5-5.15.18 PyQt5-sip-12.18.0 pyqt5-5.15.11 ultralytics-8.4.8 ultralytics-thop-2.0.18
# Mounted at /content/drive
# Conversion complete
# Converted labels: 456

# %% [markdown]
# Install dependencies & mount drive

# %%
# !pip install -q ultralytics opencv-python psutil pyqt5 torch torchvision torchaudio pynvml

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Train / Validation Split**

# %%
import os
import shutil
import random
from pathlib import Path

BASE_DIR = Path('/content/drive/MyDrive/Regnum')
IMAGES_DIR = BASE_DIR / 'Images'
LABELS_DIR = BASE_DIR / 'Labels_detection'

NEW_BASE = BASE_DIR / 'dataset_split'
TRAIN_IMG = NEW_BASE / 'images' / 'train'
TRAIN_LBL = NEW_BASE / 'labels' / 'train'
VAL_IMG   = NEW_BASE / 'images' / 'val'
VAL_LBL   = NEW_BASE / 'labels' / 'val'

for d in [TRAIN_IMG, TRAIN_LBL, VAL_IMG, VAL_LBL]:
    d.mkdir(parents=True, exist_ok=True)

image_files = list(IMAGES_DIR.glob('**/*.[jJ][pP][gG]')) + list(IMAGES_DIR.glob('**/*.[pP][nN][gG]'))
print(f"Found {len(image_files)} images")

if len(image_files) == 0:
    raise ValueError("No images found! Check path and extensions.")

print("Sample images:", [str(f) for f in image_files[:5]])

random.seed(42)
random.shuffle(image_files)
split_idx = int(0.8 * len(image_files))
train_files = image_files[:split_idx]
val_files   = image_files[split_idx:]

print(f"Train: {len(train_files)} images | Val: {len(val_files)} images")

def copy_pair(img_path, dest_img_dir, dest_lbl_dir):
    lbl_name = img_path.with_suffix('.txt').name
    lbl_path = LABELS_DIR / lbl_name
    if lbl_path.exists():
        shutil.copy(img_path, dest_img_dir / img_path.name)
        shutil.copy(lbl_path, dest_lbl_dir / lbl_name)
    else:
        print(f"Warning: No label for {img_path.name} → skipping image copy")
        return False
    return True

train_copied = 0
for img in train_files:
    if copy_pair(img, TRAIN_IMG, TRAIN_LBL):
        train_copied += 1

val_copied = 0
for img in val_files:
    if copy_pair(img, VAL_IMG, VAL_LBL):
        val_copied += 1

print(f"Train copied: {train_copied} | Val copied: {val_copied}")
print("Dataset split complete.")
# Out:
# Found 456 images
# Sample images: ['/content/drive/MyDrive/Regnum/Images/100_jpg.rf.49e80e5a51a7fac3fe774aa4a879939c.jpg', '/content/drive/MyDrive/Regnum/Images/103_jpg.rf.3229a6787fa013854a7e75d19969f258.jpg', '/content/drive/MyDrive/Regnum/Images/109_jpg.rf.a056ed245a8f7716fae3ce4d2e0c7137.jpg', '/content/drive/MyDrive/Regnum/Images/111_jpg.rf.414ed79e9747b566a22d87aa07f2f28b.jpg', '/content/drive/MyDrive/Regnum/Images/102_jpg.rf.a21da2fc12e83c9531ee46e5c9829f30.jpg']
# Train: 364 images | Val: 92 images
# Train copied: 364 | Val copied: 92
# Dataset split complete.

# %% [markdown]
# Creating data.yaml

# %%
CLASS_NAMES = [
    'Auto Rickshaw', 'Bus', 'CNG', 'Cycle Rickshaw', 'Jeep - SUV', 'Microbus', 'Motorcycle', 'Private Sedan Car', 'Tempo', 'Trailer', 'Truck'
]

yaml_content = f"""\
path: {BASE_DIR / 'dataset_split'}
train: images/train
val: images/val

nc: {len(CLASS_NAMES)}
names: {CLASS_NAMES}
"""

yaml_path = BASE_DIR / 'data.yaml'
with open(yaml_path, 'w') as f:
    f.write(yaml_content)

print(f"data.yaml created at: {yaml_path}")
# Out:
# data.yaml created at: /content/drive/MyDrive/Regnum/data.yaml

# %% [markdown]
# Training **YOLOv8m**

# %%
from ultralytics import YOLO
from pathlib import Path
import torch
import os

print("Checking GPU availability...")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available? {torch.cuda.is_available()}")
print(f"CUDA device count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    device = 'cuda:0'
    print("GPU detected! Using Tesla T4 (or similar).")
    # !nvidia-smi
else:
    device = 'cpu'
    print("WARNING: No GPU found! Falling back to CPU — training will be VERY SLOW. Enable GPU via Runtime → Change runtime type → T4 GPU → Save → Restart runtime.")


BASE_DIR = Path('/content/drive/MyDrive/Regnum')
DATA_YAML = BASE_DIR / 'data.yaml'

MODEL_SAVE_DIR = BASE_DIR / 'runs' / 'regnum_traffic_model'
LAST_WEIGHTS = MODEL_SAVE_DIR / 'weights' / 'last.pt'


if LAST_WEIGHTS.exists():
    print("Found previous checkpoint → Resuming training from last.pt")
    model = YOLO(str(LAST_WEIGHTS))
    resume = True
else:
    print("No checkpoint found → Starting fresh training with yolov8m.pt")
    model = YOLO('yolov8m.pt')
    resume = False


print(f"Using data.yaml: {DATA_YAML}")
print(f"Expected train images: {BASE_DIR / 'dataset_split' / 'images' / 'train'}")
print(f"Expected val images:   {BASE_DIR / 'dataset_split' / 'images' / 'val'}")


results = model.train(
    data=str(DATA_YAML),
    epochs=50,
    imgsz=640,
    batch=16,
    device=device,
    workers=2,
    patience=15,
    save_period=1,
    project=str(BASE_DIR / 'runs'),
    name='regnum_traffic_model',
    exist_ok=True,
    augment=True,
)

print("\n" + "="*60)
print("Training finished or stopped early.")
print(f"Best weights:   {MODEL_SAVE_DIR}/weights/best.pt")
print(f"Last checkpoint: {MODEL_SAVE_DIR}/weights/last.pt")
print(f"Logs & plots:    {MODEL_SAVE_DIR}")
print("="*60)
print(f"\nUse this for inference/GUI: {MODEL_SAVE_DIR}/weights/best.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Checking GPU availability...
# PyTorch version: 2.9.0+cu126
# CUDA available? True
# CUDA device count: 1
# GPU detected! Using Tesla T4 (or similar).
# Thu Jan 29 07:48:32 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             11W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Found previous checkpoint → Resuming training from last.pt
# Using data.yaml: /content/drive/MyDrive/Regnum/data.yaml
# Expected train images: /content/drive/MyDrive/Regnum/dataset_split/images/train
# Expected val images:   /content/drive/MyDrive/Regnum/dataset_split/images/val
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/Regnum/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=regnum_traffic_model, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/Regnum/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/Regnum/runs/regnum_traffic_model, save_frames=False, save_json=False, save_period=1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 24.1MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3782065  ultralytics.nn.modules.head.Detect           [11, 16, None, [192, 384, 576]]
# Model summary: 170 layers, 25,862,689 parameters, 25,862,673 gradients, 79.1 GFLOPs
#
# Transferred 475/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 100.3MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.6±0.4 ms, read: 21.7±10.5 MB/s, size: 49.2 KB)
# train: Scanning /content/drive/MyDrive/Regnum/dataset_split/labels/train... 439 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 439/439 127.0it/s 3.5s
# train: New cache created: /content/drive/MyDrive/Regnum/dataset_split/labels/train.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 821, len(boxes) = 4810. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 1.3±1.0 ms, read: 4.5±6.0 MB/s, size: 47.6 KB)
# val: Scanning /content/drive/MyDrive/Regnum/dataset_split/labels/val... 167 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 167/167 76.6it/s 2.2s
# val: New cache created: /content/drive/MyDrive/Regnum/dataset_split/labels/val.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 817, len(boxes) = 1869. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /content/drive/MyDrive/Regnum/runs/regnum_traffic_model/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/Regnum/runs/regnum_traffic_model
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      6.33G     0.6807     0.5573     0.9064        131        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.2it/s 2.7s
#                    all        167       1869      0.698      0.667      0.693      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      6.69G      0.706     0.5812     0.9054        131        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.1it/s 2.9s
#                    all        167       1869      0.672      0.685      0.687      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      6.76G     0.7368     0.6179     0.9171        140        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.9it/s 3.1s
#                    all        167       1869      0.745      0.558      0.634      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      6.76G     0.7593     0.6332      0.919        163        640: 100% ━━━━━━━━━━━━ 28/28 1.8it/s 15.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.3it/s 1.8s
#                    all        167       1869       0.69      0.663      0.667      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      6.76G     0.7457      0.661     0.9221        139        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s
#                    all        167       1869      0.833      0.583      0.686      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      6.76G     0.7701     0.6583     0.9207         89        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.0it/s 2.0s
#                    all        167       1869      0.855      0.568      0.697      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      6.76G     0.7665     0.6487     0.9163        166        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s
#                    all        167       1869      0.742      0.713      0.767      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      6.83G     0.7436     0.6306     0.9203        116        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s
#                    all        167       1869      0.803      0.689      0.787      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      6.89G     0.7275     0.6122     0.9114        106        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 19.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s
#                    all        167       1869       0.77      0.638      0.714      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      6.96G     0.7409     0.6214     0.9081        123        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s
#                    all        167       1869      0.765      0.631      0.724      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      7.03G      0.735     0.5967     0.9017        132        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.2s
#                    all        167       1869      0.745      0.732      0.763      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      7.03G      0.707     0.6045     0.9049        121        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all        167       1869      0.778      0.687      0.764      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      7.03G     0.7251     0.5989     0.9032        158        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.2it/s 2.7s
#                    all        167       1869      0.727      0.674      0.749      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      7.03G     0.7016     0.5636     0.9041        143        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.7it/s 3.5s
#                    all        167       1869      0.835      0.713      0.801       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      7.03G     0.7088     0.5813     0.8968        159        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s
#                    all        167       1869      0.806      0.724      0.792       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      7.03G     0.7174     0.5625     0.8975        155        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.5it/s 1.7s
#                    all        167       1869      0.856      0.663      0.797      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      7.03G     0.6723     0.5438     0.8908        143        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.5it/s 4.0s
#                    all        167       1869      0.767      0.782      0.819      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      7.03G     0.6744     0.5413     0.8933        172        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s
#                    all        167       1869      0.826      0.711       0.81      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      7.03G     0.6855     0.5318     0.8896        164        640: 100% ━━━━━━━━━━━━ 28/28 1.6it/s 17.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.1it/s 2.9s
#                    all        167       1869      0.708      0.773      0.814      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      7.03G     0.6891     0.5274     0.8865        119        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s
#                    all        167       1869      0.927      0.639       0.79      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      7.03G     0.6669     0.5235     0.8858        144        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s
#                    all        167       1869      0.876      0.734       0.83      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      7.03G     0.6651      0.518     0.8867        166        640: 100% ━━━━━━━━━━━━ 28/28 1.8it/s 15.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.5it/s 1.7s
#                    all        167       1869      0.843      0.737      0.826      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      7.03G     0.6665     0.5065     0.8762        178        640: 100% ━━━━━━━━━━━━ 28/28 1.4it/s 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s
#                    all        167       1869      0.825      0.747      0.805      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      7.03G     0.6429     0.4996     0.8782         98        640: 100% ━━━━━━━━━━━━ 28/28 1.6it/s 17.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.3it/s 2.6s
#                    all        167       1869      0.812      0.739      0.814      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      7.03G     0.6552     0.5026     0.8797        187        640: 100% ━━━━━━━━━━━━ 28/28 1.6it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s
#                    all        167       1869      0.917      0.745      0.854      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      7.03G     0.6428     0.4824     0.8707        127        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.8s
#                    all        167       1869      0.891      0.698      0.836      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      7.03G     0.6402     0.4774     0.8718        164        640: 100% ━━━━━━━━━━━━ 28/28 1.6it/s 17.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s
#                    all        167       1869      0.868      0.753      0.842      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      7.03G     0.6236     0.4742     0.8723        147        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.7it/s 2.2s
#                    all        167       1869      0.894      0.768      0.852      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      7.03G     0.6129     0.4583     0.8657        140        640: 100% ━━━━━━━━━━━━ 28/28 1.4it/s 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 3.0s
#                    all        167       1869      0.867      0.753      0.834      0.682
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      7.03G     0.6316     0.4758     0.8636         93        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.5it/s 1.7s
#                    all        167       1869      0.854      0.769      0.835      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      7.03G       0.62     0.4521     0.8748        112        640: 100% ━━━━━━━━━━━━ 28/28 1.6it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.7it/s 2.2s
#                    all        167       1869      0.865      0.739       0.85      0.703
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      7.03G     0.6153     0.4581     0.8696        223        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.0it/s 2.0s
#                    all        167       1869      0.887      0.785      0.862      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      7.03G     0.6029     0.4446     0.8624        118        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.0it/s 2.0s
#                    all        167       1869       0.87      0.772      0.855      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      7.03G     0.6087     0.4491     0.8595        129        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s
#                    all        167       1869       0.87      0.779      0.859      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      7.03G     0.5946     0.4316     0.8566        117        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s
#                    all        167       1869      0.911      0.781      0.864      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      7.03G     0.5875     0.4312     0.8546        250        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.8s
#                    all        167       1869      0.851      0.787      0.857      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      7.03G     0.5907     0.4298     0.8506        141        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 19.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.3it/s 1.8s
#                    all        167       1869      0.858      0.793      0.857      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      7.03G     0.5654     0.4135     0.8558         87        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.7it/s 2.3s
#                    all        167       1869      0.903      0.795      0.861      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      7.03G     0.5634     0.4116     0.8511        182        640: 100% ━━━━━━━━━━━━ 28/28 1.5it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.4it/s 2.5s
#                    all        167       1869      0.904      0.793      0.861      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      7.03G     0.5703     0.4023     0.8491        122        640: 100% ━━━━━━━━━━━━ 28/28 1.6it/s 17.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.7it/s 2.2s
#                    all        167       1869      0.902      0.789      0.855      0.718
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      7.03G     0.5564     0.3921      0.841         92        640: 100% ━━━━━━━━━━━━ 28/28 1.2it/s 22.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s
#                    all        167       1869      0.884      0.789      0.847      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      7.03G     0.5477     0.3707     0.8376         66        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.8s
#                    all        167       1869      0.875      0.802      0.843       0.71
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      7.03G     0.5459     0.3711     0.8347         74        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s
#                    all        167       1869      0.882      0.768      0.853      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      7.03G     0.5348     0.3636     0.8326         61        640: 100% ━━━━━━━━━━━━ 28/28 1.6it/s 17.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.4it/s 2.5s
#                    all        167       1869       0.84      0.826      0.861      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      7.03G     0.5335     0.3583      0.836         60        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.8s
#                    all        167       1869      0.869      0.818      0.865       0.73
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      7.03G     0.5225     0.3471     0.8263         77        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s
#                    all        167       1869      0.904       0.81      0.871      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      7.03G     0.5259     0.3485     0.8319         79        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s
#                    all        167       1869      0.908      0.799      0.866      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      7.03G     0.5102     0.3375     0.8298         97        640: 100% ━━━━━━━━━━━━ 28/28 1.6it/s 17.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.7s
#                    all        167       1869      0.914       0.79      0.866      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      7.03G     0.5044     0.3324     0.8193         99        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.3it/s 2.6s
#                    all        167       1869      0.915      0.791      0.865      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      7.03G     0.5154     0.3365     0.8209         64        640: 100% ━━━━━━━━━━━━ 28/28 1.7it/s 16.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s
#                    all        167       1869      0.908      0.796       0.87      0.741
#
# 50 epochs completed in 0.448 hours.
# Optimizer stripped from /content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/last.pt, 52.0MB
# Optimizer stripped from /content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/best.pt, 52.0MB
#
# Validating /content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/best.pt...
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 93 layers, 25,846,129 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.0s/it 6.1s
#                    all        167       1869      0.904      0.795      0.877      0.744
#          Auto Rickshaw         79        330      0.899      0.694      0.824      0.605
#                    Bus         92        200      0.972       0.88      0.941      0.869
#                    CNG         43         60      0.948      0.905      0.955      0.868
#         Cycle Rickshaw         47         68      0.819      0.971      0.973      0.848
#             Jeep - SUV          5          5      0.937          1      0.995      0.936
#               Microbus          6          6      0.933      0.833      0.942      0.756
#             Motorcycle         94        252      0.769      0.581      0.678      0.437
#      Private Sedan Car         73        183      0.865       0.76       0.85      0.729
#                  Tempo          5          7      0.926      0.714       0.86      0.761
#                Trailer          5          5      0.963        0.6      0.713      0.601
#                  Truck        142        753      0.917      0.804       0.91      0.775
# Speed: 0.2ms preprocess, 19.8ms inference, 0.0ms loss, 5.7ms postprocess per image
# Results saved to /content/drive/MyDrive/Regnum/runs/regnum_traffic_model
#
# ============================================================
# Training finished or stopped early.
# Best weights:   /content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/best.pt
# Last checkpoint: /content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/last.pt
# Logs & plots:    /content/drive/MyDrive/Regnum/runs/regnum_traffic_model
# ============================================================
#
# Use this for inference/GUI: /content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/best.pt

# %% [markdown]
# Export to **ONNX** & Validate Model

# %%
best_model_path = MODEL_SAVE_DIR / 'weights' / 'best.pt'
model = YOLO(str(best_model_path))
model.export(format='onnx', dynamic=True, simplify=True)

print(f"ONNX model saved: {MODEL_SAVE_DIR}/weights/best.onnx")

metrics = model.val()
print("\nValidation metrics:")
print(f"mAP@0.5     : {metrics.box.map:.4f}")
print(f"mAP@0.5:0.95: {metrics.box.map50:.4f}")
print(f"Precision   : {metrics.box.p.mean():.4f}")
print(f"Recall      : {metrics.box.r.mean():.4f}")
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 93 layers, 25,846,129 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 15, 8400) (49.6 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 14 packages in 209ms
# Prepared 6 packages in 6.02s
# Installed 6 packages in 260ms
#  + colorama==0.4.6
#  + coloredlogs==15.0.1
#  + humanfriendly==10.0
#  + onnx==1.20.1
#  + onnxruntime-gpu==1.23.2
#  + onnxslim==0.1.82
#
# requirements: AutoUpdate success ✅ 7.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.20.1 opset 22...
# /usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/torchscript_exporter/utils.py:1447: OnnxExporterWarning: Exporting to ONNX opset version 22 is not supported. by 'torch.onnx.export()'. The highest opset version supported is 20. To use a newer opset version, consider 'torch.onnx.export(..., dynamo=True)'.
#   warnings.warn(
# ONNX: slimming with onnxslim 0.1.82...
# ONNX: export success ✅ 20.1s, saved as '/content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/best.onnx' (99.3 MB)
#
# Export complete (22.9s)
# Results saved to /content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights
# Predict:         yolo predict task=detect model=/content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/best.onnx imgsz=640 data=/content/drive/MyDrive/Regnum/data.yaml
# Visualize:       https://netron.app
# ONNX model saved: /content/drive/MyDrive/Regnum/runs/regnum_traffic_model/weights/best.onnx
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 93 layers, 25,846,129 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.2 ms, read: 31.2±6.4 MB/s, size: 50.7 KB)
# val: Scanning /content/drive/MyDrive/Regnum/dataset_split/labels/val.cache... 167 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 167/167 50.0Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 817, len(boxes) = 1869. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.0it/s 5.5s
#                    all        167       1869      0.909      0.796      0.872      0.742
#          Auto Rickshaw         79        330      0.903      0.678      0.839      0.625
#                    Bus         92        200      0.961      0.875      0.936      0.864
#                    CNG         43         60      0.964      0.885      0.947      0.876
#         Cycle Rickshaw         47         68      0.848      0.971      0.983      0.863
#             Jeep - SUV          5          5      0.933          1      0.995      0.937
#               Microbus          6          6      0.927      0.833      0.862      0.669
#             Motorcycle         94        252      0.878        0.6      0.721      0.448
#      Private Sedan Car         73        183      0.865       0.77      0.858      0.743
#                  Tempo          5          7      0.909      0.714      0.846      0.739
#                Trailer          5          5        0.9        0.6      0.692      0.612
#                  Truck        142        753      0.913      0.834      0.915      0.783
# Speed: 3.5ms preprocess, 13.2ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to /content/runs/detect/val
#
# Validation metrics:
# mAP@0.5     : 0.7418
# mAP@0.5:0.95: 0.8721
# Precision   : 0.9092
# Recall      : 0.7964

# %% [markdown]
# Full Video Processing

# %%
from ultralytics import YOLO
import cv2
import time
import numpy as np
from collections import deque
from pathlib import Path

BASE_DIR = Path('/content/drive/MyDrive/Regnum')
VIDEO_PATH = BASE_DIR / 'Video' / 'Supporting video for Dataset-2.mp4'
FULL_OUTPUT = BASE_DIR / 'full_processed_Dataset2.mp4'
MODEL_PATH = BASE_DIR / 'runs' / 'regnum_traffic_model' / 'weights' / 'best.pt'

for p, name in [(VIDEO_PATH, "Video"), (MODEL_PATH, "Model")]:
    if not p.exists():
        print(f"Error: {name} not found → {p}")
        raise FileNotFoundError(f"{name} missing")

print("Loading model...")
model = YOLO(str(MODEL_PATH))
print("Model loaded OK")

cap = cv2.VideoCapture(str(VIDEO_PATH))
if not cap.isOpened():
    raise RuntimeError("Cannot open video")

fps_src = cap.get(cv2.CAP_PROP_FPS)
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

print(f"Video: {w}x{h} @ {fps_src:.1f} FPS | {total_frames} frames (~{total_frames/fps_src:.0f} sec)")

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(str(FULL_OUTPUT), fourcc, fps_src, (w, h))

frame_count = 0
times = []
fps_history = deque(maxlen=30)
start_total = time.time()

print("Starting full inference...")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("End of video reached.")
        break

    t0 = time.time()
    results = model.track(frame, persist=True, tracker="botsort.yaml", verbose=False)
    t1 = time.time()

    process_time = t1 - t0
    times.append(process_time)
    current_fps = 1 / process_time if process_time > 0 else 0
    fps_history.append(current_fps)

    annotated = results[0].plot() if results[0].boxes is not None else frame.copy()
    out.write(annotated)

    frame_count += 1

    if frame_count % 50 == 0:
        avg_so_far = sum(fps_history) / len(fps_history) if fps_history else 0
        elapsed = time.time() - start_total
        eta_min = ((total_frames - frame_count) * (elapsed / frame_count)) / 60 if frame_count > 0 else 0
        print(f"Frame {frame_count:6d}/{total_frames} | "
              f"Inst FPS: {current_fps:.1f} | Avg: {avg_so_far:.1f} | ETA ~{eta_min:.1f} min")

cap.release()
out.release()

total_time = time.time() - start_total
avg_fps = len(times) / sum(times) if times else 0

print("\n" + "="*70)
print(f"Finished – processed {frame_count} / {total_frames} frames")
print(f"Total wall time: {total_time:.1f} s")
print(f"Average FPS: {avg_fps:.1f}")
print(f"Saved to: {FULL_OUTPUT}")
print("="*70)
# Out:
# Loading model...
# Model loaded OK
# Video: 1920x1080 @ 25.0 FPS | 7501 frames (~300 sec)
# Starting full inference...
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 2 packages in 420ms
# Prepared 1 package in 92ms
# Installed 1 package in 9ms
#  + lap==0.5.12
#
# requirements: AutoUpdate success ✅ 1.3s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# Frame     50/7501 | Inst FPS: 16.4 | Avg: 16.3 | ETA ~22.3 min
# Frame    100/7501 | Inst FPS: 16.8 | Avg: 16.6 | ETA ~16.4 min
# Frame    150/7501 | Inst FPS: 15.8 | Avg: 12.8 | ETA ~15.2 min
# Frame    200/7501 | Inst FPS: 16.3 | Avg: 16.3 | ETA ~14.1 min
# Frame    250/7501 | Inst FPS: 16.1 | Avg: 16.5 | ETA ~13.3 min
# Frame    300/7501 | Inst FPS: 16.4 | Avg: 14.1 | ETA ~13.1 min
# Frame    350/7501 | Inst FPS: 16.9 | Avg: 16.5 | ETA ~12.7 min
# Frame    400/7501 | Inst FPS: 16.2 | Avg: 16.5 | ETA ~12.3 min
# Frame    450/7501 | Inst FPS: 17.1 | Avg: 15.3 | ETA ~12.3 min
# Frame    500/7501 | Inst FPS: 15.5 | Avg: 16.5 | ETA ~12.0 min
# Frame    550/7501 | Inst FPS: 13.2 | Avg: 15.3 | ETA ~11.8 min
# Frame    600/7501 | Inst FPS: 16.9 | Avg: 16.6 | ETA ~11.7 min
# Frame    650/7501 | Inst FPS: 16.7 | Avg: 16.4 | ETA ~11.5 min
# Frame    700/7501 | Inst FPS: 13.3 | Avg: 14.4 | ETA ~11.4 min
# Frame    750/7501 | Inst FPS: 16.6 | Avg: 16.1 | ETA ~11.4 min
# Frame    800/7501 | Inst FPS: 17.2 | Avg: 16.5 | ETA ~11.2 min
# Frame    850/7501 | Inst FPS: 16.4 | Avg: 13.1 | ETA ~11.1 min
# Frame    900/7501 | Inst FPS: 16.1 | Avg: 16.2 | ETA ~11.0 min
# Frame    950/7501 | Inst FPS: 16.4 | Avg: 16.0 | ETA ~10.9 min
# Frame   1000/7501 | Inst FPS: 16.2 | Avg: 15.0 | ETA ~10.9 min
# Frame   1050/7501 | Inst FPS: 16.6 | Avg: 16.2 | ETA ~10.8 min
# Frame   1100/7501 | Inst FPS: 12.5 | Avg: 14.5 | ETA ~10.7 min
# Frame   1150/7501 | Inst FPS: 15.6 | Avg: 16.1 | ETA ~10.6 min
# Frame   1200/7501 | Inst FPS: 3.9 | Avg: 15.5 | ETA ~10.5 min
# Frame   1250/7501 | Inst FPS: 16.4 | Avg: 13.4 | ETA ~10.5 min
# Frame   1300/7501 | Inst FPS: 14.9 | Avg: 16.1 | ETA ~10.4 min
# Frame   1350/7501 | Inst FPS: 16.9 | Avg: 16.4 | ETA ~10.3 min
# Frame   1400/7501 | Inst FPS: 16.2 | Avg: 15.0 | ETA ~10.2 min
# Frame   1450/7501 | Inst FPS: 16.9 | Avg: 16.6 | ETA ~10.1 min
# Frame   1500/7501 | Inst FPS: 13.2 | Avg: 15.6 | ETA ~10.0 min
# Frame   1550/7501 | Inst FPS: 16.3 | Avg: 16.3 | ETA ~9.9 min
# Frame   1600/7501 | Inst FPS: 16.4 | Avg: 16.3 | ETA ~9.8 min
# Frame   1650/7501 | Inst FPS: 12.2 | Avg: 14.0 | ETA ~9.7 min
# Frame   1700/7501 | Inst FPS: 16.4 | Avg: 16.2 | ETA ~9.6 min
# Frame   1750/7501 | Inst FPS: 16.8 | Avg: 16.6 | ETA ~9.5 min
# Frame   1800/7501 | Inst FPS: 16.6 | Avg: 13.0 | ETA ~9.4 min
# Frame   1850/7501 | Inst FPS: 13.8 | Avg: 16.4 | ETA ~9.3 min
# Frame   1900/7501 | Inst FPS: 16.6 | Avg: 16.3 | ETA ~9.2 min
# Frame   1950/7501 | Inst FPS: 16.0 | Avg: 13.9 | ETA ~9.2 min
# Frame   2000/7501 | Inst FPS: 16.5 | Avg: 16.3 | ETA ~9.1 min
# Frame   2050/7501 | Inst FPS: 13.1 | Avg: 16.0 | ETA ~9.0 min
# Frame   2100/7501 | Inst FPS: 17.1 | Avg: 16.0 | ETA ~8.9 min
# Frame   2150/7501 | Inst FPS: 17.2 | Avg: 16.7 | ETA ~8.8 min
# Frame   2200/7501 | Inst FPS: 13.4 | Avg: 16.0 | ETA ~8.7 min
# Frame   2250/7501 | Inst FPS: 16.2 | Avg: 16.3 | ETA ~8.6 min
# Frame   2300/7501 | Inst FPS: 16.7 | Avg: 16.0 | ETA ~8.5 min
# Frame   2350/7501 | Inst FPS: 13.4 | Avg: 13.9 | ETA ~8.4 min
# Frame   2400/7501 | Inst FPS: 16.9 | Avg: 16.6 | ETA ~8.4 min
# Frame   2450/7501 | Inst FPS: 16.8 | Avg: 16.4 | ETA ~8.3 min
# Frame   2500/7501 | Inst FPS: 16.4 | Avg: 13.1 | ETA ~8.2 min
# Frame   2550/7501 | Inst FPS: 16.7 | Avg: 16.3 | ETA ~8.1 min
# Frame   2600/7501 | Inst FPS: 17.3 | Avg: 16.6 | ETA ~8.0 min
# Frame   2650/7501 | Inst FPS: 16.4 | Avg: 14.9 | ETA ~7.9 min
# Frame   2700/7501 | Inst FPS: 16.3 | Avg: 16.3 | ETA ~7.8 min
# Frame   2750/7501 | Inst FPS: 12.9 | Avg: 15.5 | ETA ~7.8 min
# Frame   2800/7501 | Inst FPS: 16.8 | Avg: 16.2 | ETA ~7.7 min
# Frame   2850/7501 | Inst FPS: 16.9 | Avg: 16.8 | ETA ~7.6 min
# Frame   2900/7501 | Inst FPS: 12.6 | Avg: 14.9 | ETA ~7.5 min
# Frame   2950/7501 | Inst FPS: 15.2 | Avg: 16.1 | ETA ~7.4 min
# Frame   3000/7501 | Inst FPS: 16.4 | Avg: 16.2 | ETA ~7.3 min
# Frame   3050/7501 | Inst FPS: 12.5 | Avg: 12.5 | ETA ~7.3 min
# Frame   3100/7501 | Inst FPS: 15.7 | Avg: 16.1 | ETA ~7.2 min
# Frame   3150/7501 | Inst FPS: 15.3 | Avg: 16.1 | ETA ~7.1 min
# Frame   3200/7501 | Inst FPS: 16.6 | Avg: 13.9 | ETA ~7.0 min
# Frame   3250/7501 | Inst FPS: 16.3 | Avg: 16.1 | ETA ~6.9 min
# Frame   3300/7501 | Inst FPS: 10.5 | Avg: 15.8 | ETA ~6.8 min
# Frame   3350/7501 | Inst FPS: 15.6 | Avg: 15.8 | ETA ~6.8 min
# Frame   3400/7501 | Inst FPS: 16.1 | Avg: 15.9 | ETA ~6.7 min
# Frame   3450/7501 | Inst FPS: 12.1 | Avg: 13.5 | ETA ~6.6 min
# Frame   3500/7501 | Inst FPS: 16.5 | Avg: 16.3 | ETA ~6.5 min
# Frame   3550/7501 | Inst FPS: 16.3 | Avg: 16.5 | ETA ~6.4 min
# Frame   3600/7501 | Inst FPS: 16.9 | Avg: 13.0 | ETA ~6.4 min
# Frame   3650/7501 | Inst FPS: 16.9 | Avg: 16.7 | ETA ~6.3 min
# Frame   3700/7501 | Inst FPS: 16.8 | Avg: 16.3 | ETA ~6.2 min
# Frame   3750/7501 | Inst FPS: 16.7 | Avg: 14.1 | ETA ~6.1 min
# Frame   3800/7501 | Inst FPS: 16.1 | Avg: 16.1 | ETA ~6.0 min
# Frame   3850/7501 | Inst FPS: 12.0 | Avg: 15.6 | ETA ~5.9 min
# Frame   3900/7501 | Inst FPS: 16.2 | Avg: 15.8 | ETA ~5.9 min
# Frame   3950/7501 | Inst FPS: 16.5 | Avg: 16.4 | ETA ~5.8 min
# Frame   4000/7501 | Inst FPS: 12.8 | Avg: 13.7 | ETA ~5.7 min
# Frame   4050/7501 | Inst FPS: 16.0 | Avg: 15.9 | ETA ~5.6 min
# Frame   4100/7501 | Inst FPS: 16.4 | Avg: 15.8 | ETA ~5.5 min
# Frame   4150/7501 | Inst FPS: 16.7 | Avg: 13.7 | ETA ~5.5 min
# Frame   4200/7501 | Inst FPS: 12.5 | Avg: 16.0 | ETA ~5.4 min
# Frame   4250/7501 | Inst FPS: 12.5 | Avg: 14.2 | ETA ~5.3 min
# Frame   4300/7501 | Inst FPS: 16.7 | Avg: 16.2 | ETA ~5.2 min
# Frame   4350/7501 | Inst FPS: 16.4 | Avg: 16.3 | ETA ~5.2 min
# Frame   4400/7501 | Inst FPS: 16.2 | Avg: 12.8 | ETA ~5.1 min
# Frame   4450/7501 | Inst FPS: 15.7 | Avg: 15.8 | ETA ~5.0 min
# Frame   4500/7501 | Inst FPS: 16.5 | Avg: 16.1 | ETA ~4.9 min
# Frame   4550/7501 | Inst FPS: 16.1 | Avg: 15.0 | ETA ~4.8 min
# Frame   4600/7501 | Inst FPS: 16.4 | Avg: 16.3 | ETA ~4.7 min
# Frame   4650/7501 | Inst FPS: 11.4 | Avg: 14.7 | ETA ~4.7 min
# Frame   4700/7501 | Inst FPS: 16.2 | Avg: 15.9 | ETA ~4.6 min
# Frame   4750/7501 | Inst FPS: 13.9 | Avg: 16.0 | ETA ~4.5 min
# Frame   4800/7501 | Inst FPS: 16.2 | Avg: 12.4 | ETA ~4.4 min
# Frame   4850/7501 | Inst FPS: 16.1 | Avg: 16.5 | ETA ~4.3 min
# Frame   4900/7501 | Inst FPS: 16.4 | Avg: 16.4 | ETA ~4.3 min
# Frame   4950/7501 | Inst FPS: 14.7 | Avg: 14.0 | ETA ~4.2 min
# Frame   5000/7501 | Inst FPS: 16.7 | Avg: 16.5 | ETA ~4.1 min
# Frame   5050/7501 | Inst FPS: 11.6 | Avg: 15.4 | ETA ~4.0 min
# Frame   5100/7501 | Inst FPS: 16.3 | Avg: 15.8 | ETA ~3.9 min
# Frame   5150/7501 | Inst FPS: 16.8 | Avg: 16.2 | ETA ~3.8 min
# Frame   5200/7501 | Inst FPS: 12.4 | Avg: 13.4 | ETA ~3.8 min
# Frame   5250/7501 | Inst FPS: 16.3 | Avg: 15.7 | ETA ~3.7 min
# Frame   5300/7501 | Inst FPS: 16.1 | Avg: 16.1 | ETA ~3.6 min
# Frame   5350/7501 | Inst FPS: 16.5 | Avg: 14.3 | ETA ~3.5 min
# Frame   5400/7501 | Inst FPS: 17.0 | Avg: 16.4 | ETA ~3.4 min
# Frame   5450/7501 | Inst FPS: 11.2 | Avg: 15.6 | ETA ~3.4 min
# Frame   5500/7501 | Inst FPS: 16.6 | Avg: 16.3 | ETA ~3.3 min
# Frame   5550/7501 | Inst FPS: 15.7 | Avg: 16.4 | ETA ~3.2 min
# Frame   5600/7501 | Inst FPS: 10.9 | Avg: 13.4 | ETA ~3.1 min
# Frame   5650/7501 | Inst FPS: 16.5 | Avg: 16.4 | ETA ~3.0 min
# Frame   5700/7501 | Inst FPS: 16.8 | Avg: 16.5 | ETA ~3.0 min
# Frame   5750/7501 | Inst FPS: 16.9 | Avg: 13.6 | ETA ~2.9 min
# Frame   5800/7501 | Inst FPS: 16.4 | Avg: 16.9 | ETA ~2.8 min
# Frame   5850/7501 | Inst FPS: 16.2 | Avg: 16.9 | ETA ~2.7 min
# Frame   5900/7501 | Inst FPS: 17.2 | Avg: 14.1 | ETA ~2.6 min
# Frame   5950/7501 | Inst FPS: 16.3 | Avg: 16.6 | ETA ~2.5 min
# Frame   6000/7501 | Inst FPS: 15.3 | Avg: 16.0 | ETA ~2.5 min
# Frame   6050/7501 | Inst FPS: 13.6 | Avg: 14.3 | ETA ~2.4 min
# Frame   6100/7501 | Inst FPS: 16.6 | Avg: 16.3 | ETA ~2.3 min
# Frame   6150/7501 | Inst FPS: 17.2 | Avg: 16.4 | ETA ~2.2 min
# Frame   6200/7501 | Inst FPS: 16.4 | Avg: 15.3 | ETA ~2.1 min
# Frame   6250/7501 | Inst FPS: 16.8 | Avg: 16.3 | ETA ~2.0 min
# Frame   6300/7501 | Inst FPS: 12.1 | Avg: 15.2 | ETA ~2.0 min
# Frame   6350/7501 | Inst FPS: 16.0 | Avg: 16.3 | ETA ~1.9 min
# Frame   6400/7501 | Inst FPS: 17.2 | Avg: 16.2 | ETA ~1.8 min
# Frame   6450/7501 | Inst FPS: 12.9 | Avg: 14.1 | ETA ~1.7 min
# Frame   6500/7501 | Inst FPS: 16.7 | Avg: 16.3 | ETA ~1.6 min
# Frame   6550/7501 | Inst FPS: 16.8 | Avg: 16.7 | ETA ~1.5 min
# Frame   6600/7501 | Inst FPS: 12.6 | Avg: 13.2 | ETA ~1.5 min
# Frame   6650/7501 | Inst FPS: 16.8 | Avg: 16.3 | ETA ~1.4 min
# Frame   6700/7501 | Inst FPS: 16.5 | Avg: 16.2 | ETA ~1.3 min
# Frame   6750/7501 | Inst FPS: 16.9 | Avg: 13.3 | ETA ~1.2 min
# Frame   6800/7501 | Inst FPS: 16.7 | Avg: 16.6 | ETA ~1.1 min
# Frame   6850/7501 | Inst FPS: 16.5 | Avg: 16.4 | ETA ~1.1 min
# Frame   6900/7501 | Inst FPS: 16.7 | Avg: 14.6 | ETA ~1.0 min
# Frame   6950/7501 | Inst FPS: 16.8 | Avg: 16.7 | ETA ~0.9 min
# Frame   7000/7501 | Inst FPS: 17.2 | Avg: 17.0 | ETA ~0.8 min
# Frame   7050/7501 | Inst FPS: 17.1 | Avg: 15.6 | ETA ~0.7 min
# Frame   7100/7501 | Inst FPS: 16.2 | Avg: 16.6 | ETA ~0.7 min
# Frame   7150/7501 | Inst FPS: 12.8 | Avg: 15.4 | ETA ~0.6 min
# Frame   7200/7501 | Inst FPS: 16.5 | Avg: 16.2 | ETA ~0.5 min
# Frame   7250/7501 | Inst FPS: 15.9 | Avg: 16.5 | ETA ~0.4 min
# Frame   7300/7501 | Inst FPS: 11.7 | Avg: 14.6 | ETA ~0.3 min
# Frame   7350/7501 | Inst FPS: 16.5 | Avg: 16.3 | ETA ~0.2 min
# Frame   7400/7501 | Inst FPS: 16.1 | Avg: 16.4 | ETA ~0.2 min
# Frame   7450/7501 | Inst FPS: 16.4 | Avg: 12.9 | ETA ~0.1 min
# Frame   7500/7501 | Inst FPS: 16.3 | Avg: 16.2 | ETA ~0.0 min
# End of video reached.
#
# ======================================================================
# Finished – processed 7501 / 7501 frames
# Total wall time: 729.9 s
# Average FPS: 15.2
# Saved to: /content/drive/MyDrive/Regnum/full_processed_Dataset2.mp4
# ======================================================================
